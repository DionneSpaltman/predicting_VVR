# %% [markdown]
# # Output

# %% [markdown]
# ## Dummy

# %% [markdown]
# Dummy Accuracy: 0.7727272727272727
#
# Dummy Classification Report:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.77      | 1.00   | 0.87     | 17      |
# | 1            | 0.00      | 0.00   | 0.00     | 5       |
# | accuracy     |           |        | 0.77     | 22      |
# | macro avg    | 0.39      | 0.50   | 0.44     | 22      |
# | weighted avg | 0.60      | 0.77   | 0.67     | 22      |
#
# Dummy Confusion Matrix:
# |       | 0  |     |
# |-------|----|-----|
# | 0     | 17 | 0   |
# | 1     | 5  | 0   |

# %% [markdown]
# ## Random Forest

# %% [markdown]
# Evaluating RandomForest on validation data
# RandomForest Accuracy: 0.6818181818181818
#
# RandomForest Classification Report:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.75      | 0.88   | 0.81     | 17      |
# | 1            | 0.00      | 0.00   | 0.00     | 5       |
# | accuracy     |           |        | 0.68     | 22      |
# | macro avg    | 0.38      | 0.44   | 0.41     | 22      |
# | weighted avg | 0.58      | 0.68   | 0.63     | 22      |
#
# RandomForest Confusion Matrix:
# |       | 0  | 1  |
# |-------|----|----|
# | 0     | 15 | 2  |
# | 1     | 5  | 0  |

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Evaluating MLP on validation data
# MLP Accuracy: 0.5
#
# MLP Classification Report:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.71      | 0.59   | 0.65     | 17      |
# | 1            | 0.12      | 0.20   | 0.15     | 5       |
# | accuracy     |           |        | 0.50     | 22      |
# | macro avg    | 0.42      | 0.39   | 0.40     | 22      |
# | weighted avg | 0.58      | 0.50   | 0.53     | 22      |
#
# MLP Confusion Matrix:
# |       | 0  | 1  |
# |-------|----|----|
# | 0     | 10 | 7  |
# | 1     | 4  | 1  |

# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# Evaluating SVM on validation data
# SVM Accuracy: 0.6818181818181818
#
# SVM Classification Report:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.75      | 0.88   | 0.81     | 17      |
# | 1            | 0.00      | 0.00   | 0.00     | 5       |
# | accuracy     |           |        | 0.68     | 22      |
# | macro avg    | 0.38      | 0.44   | 0.41     | 22      |
# | weighted avg | 0.58      | 0.68   | 0.63     | 22      |
#
# SVM Confusion Matrix:
# |       | 0  | 1  |
# |-------|----|----|
# | 0     | 15 | 2  |
# | 1     | 5  | 0  |

# %% [markdown]
# ## Multiclass SVM

# %% [markdown]
# Evaluating Multiclass SVM on validation data
# Multiclass SVM Accuracy: 0.6818181818181818
#
# Multiclass SVM Classification Report:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.75      | 0.88   | 0.81     | 17      |
# | 1            | 0.00      | 0.00   | 0.00     | 5       |
# | accuracy     |           |        | 0.68     | 22      |
# | macro avg    | 0.38      | 0.44   | 0.41     | 22      |
# | weighted avg | 0.58      | 0.68   | 0.63     | 22      |
#
# Multiclass SVM Confusion Matrix:
# |       | 0  | 1  |
# |-------|----|----|
# | 0     | 15 | 2  |
# | 1     | 5  | 0  |

# %% [markdown]
# ## XGBoost

# %% [markdown]
# Evaluating XGBoost on validation data
# XGBoost Accuracy: 0.8181818181818182
#
# XGBoost Classification Report:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.84      | 0.94   | 0.89     | 17      |
# | 1            | 0.67      | 0.40   | 0.50     | 5       |
# | accuracy     |           |        | 0.82     | 22      |
# | macro avg    | 0.75      | 0.67   | 0.69     | 22      |
# | weighted avg | 0.80      | 0.82   | 0.80     | 22      |
#
# XGBoost Confusion Matrix:
# |       | 0  | 1  |
# |-------|----|----|
# | 0     | 16 | 1  |
# | 1     | 3  | 2  |
#
#
# Predicting on test using XGBoost
# XGBoost Accuracy on Test Data: 0.782608695652174
#
# XGBoost Classification Report on Test Data:
# |              | precision | recall | f1-score | support |
# |--------------|-----------|--------|----------|---------|
# | 0            | 0.85      | 0.89   | 0.87     | 19      |
# | 1            | 0.33      | 0.25   | 0.29     | 4       |
# | accuracy     |           |        | 0.78     | 23      |
# | macro avg    | 0.59      | 0.57   | 0.58     | 23      |
# | weighted avg | 0.76      | 0.78   | 0.77     | 23      |
