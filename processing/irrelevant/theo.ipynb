# %% [markdown]
# # Theo's data

# %%
import pandas as pd

# %%
theo = pd.read_csv('/Users/dionnespaltman/Downloads/timeframe_4_modified_final_features.csv')

# %%
display(theo)
# Out:
#       ID  ASI_sum  index   AU01_r__sum_values   AU01_r__variance  \
# 0      7        1      7              7125.50           0.333478
# 1     23        1     23              5748.07           0.360035
# 2     24        1     24             10472.95           0.426824
# 3     25        1     25              7658.36           0.511603
# 4     26        1     26             10039.93           0.822702
# ..   ...      ...    ...                  ...                ...
# 108  142        1    142             12641.01           0.685726
# 109  143        1    143             14326.65           0.721425
# 110  144        1    144              8288.74           0.448180
# 111  145        0    145             12050.02           0.503973
# 112  146        1    146             10924.30           0.222700
#
#       AU01_r__standard_deviation   AU01_r__maximum   AU01_r__minimum  \
# 0                       0.577475              5.00               0.0
# ...

# %%
dionne = pd.read_csv('/Users/dionnespaltman/Desktop/V3/merged_df.csv')

# %%
display(dionne)
# Out:
#      Unnamed: 0   ID  sum_12  sum_4567  sum_456  VVR_group  Condition  \
# 0             0   23    24.0      37.0     27.0          0          2
# 1             1   24    23.0      37.0     28.0          0          2
# 2             2   25    28.0      44.0     33.0          1          2
# 3             3   26    30.0      37.0     29.0          0          1
# 4             4   27    22.0      39.0     31.0          1          2
# ..          ...  ...     ...       ...      ...        ...        ...
# 106         106  142    20.0      34.0     26.0          0          3
# 107         107  143    25.0      48.0     36.0          1          3
# 108         108  144    24.0      35.0     27.0          0          3
# 109         109  145    20.0      37.0     28.0          0          1
# 110         110  146    22.0      40.0     32.0          1          2
#
#      AU01_r__sum_values  AU01_r__variance  AU01_r__standard_deviation  ...  \
# ...
