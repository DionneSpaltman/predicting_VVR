# %% [markdown]
# # Temporary file for Random Forest - creating files with the same amount of rows

# %% [markdown]
# In this code I'm only using the data of 177 participants.

# %%
import numpy as np
import pandas as pd
import csv

# %%
file_path_extracted_features = '/Users/dionnespaltman/Desktop/downloading_new/extracted_features_clean_incomplete.csv'

# Read the pickle file into a DataFrame
extracted_features_incomplete = pd.read_csv(file_path_extracted_features)

extracted_features_incomplete.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)

# Display the DataFrame
display(extracted_features_incomplete)

print(len(extracted_features_incomplete))
# Out:
#       ID   AU01_r__sum_values   AU01_r__variance   AU01_r__standard_deviation  \
# 0      5              6142.65           0.233452                     0.483169
# 1      6              6802.40           0.437904                     0.661743
# 2      7              7125.50           0.333478                     0.577475
# 3      8              5542.21           0.222518                     0.471719
# 4      9              5854.51           0.164812                     0.405970
# ..   ...                  ...                ...                          ...
# 178  328              1543.09           0.225924                     0.475314
# 179  329              1479.36           0.138269                     0.371846
# 180  330              1066.31           0.078431                     0.280056
# 181  331              1691.75           0.216956                     0.465785
# 182  332              1283.27           0.152346                     0.390315
#
# ...

# %%
# load the donor info file
donor_info_path = '/Users/dionnespaltman/Desktop/downloading_new/faint_info_final.csv'
donor_info = pd.read_csv(donor_info_path)
display(donor_info)

print(len(donor_info))
# Out:
#      Unnamed: 0   ID  Time_point  Gender   Age       Datum  Location  \
# 0             0    5        -1.0       2  33.0  21-10-2019         0
# 1             1    6        -1.0       1  33.0  25-10-2019         0
# 2             2    7        -1.0       2  25.0  28-10-2019         0
# 3             3    8        -1.0       1  56.0  30-10-2019         0
# 4             4    9        -1.0       1  41.0  31-10-2019         0
# ..          ...  ...         ...     ...   ...         ...       ...
# 315         315  328        -1.0       2  33.0  23-11-2022         3
# 316         316  329        -1.0       2  59.0  28-11-2022         3
# 317         317  330        -1.0       2  49.0  30-11-2022         0
# 318         318  331        -1.0       2  56.0  30-11-2022         0
# 319         319  332        -1.0       2  21.0  19-12-2022         3
#
#      Condition  Weight  Length  ...  Weaknessn  Lightheadednessn  Fearn  \
# ...

# %%
# Filter IDs in donor_info based on extracted_features_incomplete
filtered_donor_info = donor_info[donor_info['ID'].isin(extracted_features_incomplete['ID'])]

print(len(filtered_donor_info))
# Out:
# 177

# %%
# Find IDs present in extracted_features_incomplete but missing in donor_info
missing_ids = extracted_features_incomplete[~extracted_features_incomplete['ID'].isin(donor_info['ID'])]['ID']

# Display the missing IDs
print("Missing IDs:", missing_ids)
# Out:
# Missing IDs: 6       11
# 15      20
# 50      55
# 82      89
# 98     105
# 103    110
# Name: ID, dtype: int64

# %%
# Filter IDs in extracted_features_incomplete based on filtered_donor_info
filtered_extracted_features = extracted_features_incomplete[extracted_features_incomplete['ID'].isin(filtered_donor_info['ID'])]

# Now filtered_extracted_features contains only the rows with IDs present in filtered_donor_info
print(len(filtered_extracted_features))
# Out:
# 177

# %% [markdown]
# ## Merging files

# %%
# Merge filtered_donor_info and filtered_extracted_features on the 'ID' column
merged_df = pd.merge(filtered_donor_info, filtered_extracted_features, on='ID')

# Now merged_df contains both donor information and extracted features for the shared IDs

display(merged_df)
# Out:
#      Unnamed: 0   ID  Time_point  Gender   Age       Datum  Location  \
# 0             0    5        -1.0       2  33.0  21-10-2019         0
# 1             1    6        -1.0       1  33.0  25-10-2019         0
# 2             2    7        -1.0       2  25.0  28-10-2019         0
# 3             3    8        -1.0       1  56.0  30-10-2019         0
# 4             4    9        -1.0       1  41.0  31-10-2019         0
# ..          ...  ...         ...     ...   ...         ...       ...
# 172         315  328        -1.0       2  33.0  23-11-2022         3
# 173         316  329        -1.0       2  59.0  28-11-2022         3
# 174         317  330        -1.0       2  49.0  30-11-2022         0
# 175         318  331        -1.0       2  56.0  30-11-2022         0
# 176         319  332        -1.0       2  21.0  19-12-2022         3
#
#      Condition  Weight  Length  ...   AU26_r__minimum   AU26_r__mean  \
# ...

# %%
print(merged_df.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'Time_point', 'Gender', 'Age', 'Datum', 'Location',
#        'Condition', 'Weight', 'Length',
#        ...
#        ' AU26_r__minimum', ' AU26_r__mean', ' AU26_r__mean_abs_change',
#        ' AU45_r__sum_values', ' AU45_r__variance',
#        ' AU45_r__standard_deviation', ' AU45_r__maximum', ' AU45_r__minimum',
#        ' AU45_r__mean', ' AU45_r__mean_abs_change'],
#       dtype='object', length=155)

# %%
# Create your X and y variables
# Assuming 'target_variable' is the column in merged_df indicating low or high VVR group
X = merged_df.drop(['ID', 'VVR_group', 'Unnamed: 0', 'Time_point', 'Gender', 'Age', 'Datum', 'Location',
       'Condition', 'Weight', 'Length', 'FEAR_sum', 'VVR_sum_tp', 'VVR_psych_tp', 'VVR_phys_tp', 'Faintness',
       'Dizziness', 'Weakness', 'Lightheadedness', 'Fear', 'Tension', 'Stress', 'Nervousness', 'Physical_sum', 'Psychological_sum',
       'Faintnessn', 'Dizzinessn', 'Weaknessn', 'Lightheadednessn', 'Fearn',
       'Tensionn', 'Stressn', 'Nervousnessn', 'na.rm', 'sumVVR_total', 'sumVVR_456'], axis=1)  # Features excluding 'ID' and target variable
y = merged_df['VVR_group']  # Target variable

# Now you can proceed with your random forest model using X and y

# %%
print(X.columns)
print(len(X.columns))
# Out:
# Index([' AU01_r__sum_values', ' AU01_r__variance',
#        ' AU01_r__standard_deviation', ' AU01_r__maximum', ' AU01_r__minimum',
#        ' AU01_r__mean', ' AU01_r__mean_abs_change', ' AU02_r__sum_values',
#        ' AU02_r__variance', ' AU02_r__standard_deviation',
#        ...
#        ' AU26_r__minimum', ' AU26_r__mean', ' AU26_r__mean_abs_change',
#        ' AU45_r__sum_values', ' AU45_r__variance',
#        ' AU45_r__standard_deviation', ' AU45_r__maximum', ' AU45_r__minimum',
#        ' AU45_r__mean', ' AU45_r__mean_abs_change'],
#       dtype='object', length=119)
# 119

# %% [markdown]
# ## Running Random Forest

# %%
from sklearn.model_selection import train_test_split
# implementing train-test-split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=66)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=66)

# %%
# from imblearn.over_sampling import SMOTE

# # Apply SMOTE to the training data
# smote = SMOTE(random_state=42)
# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
import imblearn
print(imblearn.__version__)
# Out:
# 0.10.1

# %%
from imblearn.over_sampling import SMOTE
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import classification_report, confusion_matrix

# SMOTE toepassen om de dataset te balanceren
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Random Forest Classifier initialiseren en trainen met de gebalanceerde dataset
rf_smote = RandomForestClassifier(n_estimators=100, random_state=42)
rf_smote.fit(X_train_smote, y_train_smote)

# Voorspellingen doen op de testset
y_pred_smote = rf_smote.predict(X_test)
print(classification_report(y_test, y_pred_smote))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 8
#       6 # SMOTE toepassen om de dataset te balanceren
#       7 smote = SMOTE(random_state=42)
# ----> 8 X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
#      10 # Random Forest Classifier initialiseren en trainen met de gebalanceerde dataset
#      11 rf_smote = RandomForestClassifier(n_estimators=100, random_state=42)
#
# File ~/anaconda3/lib/python3.10/site-packages/imblearn/base.py:203, in BaseSampler.fit_resample(self, X, y)
#     182 """Resample the dataset.
#     183
#     184 Parameters
#    (...)
#     200     The corresponding label of `X_resampled`.
#     201 """
#     202 self._validate_params()
# --> 203 return super().fit_resample(X, y)
#
# File ~/anaconda3/lib/python3.10/site-packages/imblearn/base.py:88, in SamplerMixin.fit_resample(self, X, y)
# ...

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier 

# random forest model creation
rfc = RandomForestClassifier()
rfc.fit(X_train_resampled, y_train_resampled)

# predictions
rfc_predict = rfc.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
rfc_cv_score = cross_val_score(rfc, X, y, cv=10, scoring='roc_auc')

# %%
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, rfc_predict))
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Random Forest: ", rfc_cv_score.mean())
# Out:
# === Confusion Matrix ===
# [[38  8]
#  [12  1]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79        46
#            1       0.11      0.08      0.09        13
#
#     accuracy                           0.66        59
#    macro avg       0.44      0.45      0.44        59
# weighted avg       0.62      0.66      0.64        59
#
#
#
# === All AUC Scores ===
# [0.41071429 0.53571429 0.72307692 0.62307692 0.79230769 0.4
#  0.61538462 0.59615385 0.29807692 0.43269231]
#
#
# === Mean AUC Score ===
# Mean AUC Score - Random Forest:  0.5427197802197803

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# number of features at every split
max_features = ['auto', 'sqrt']

# max depth
max_depth = [int(x) for x in np.linspace(100, 500, num = 11)]
max_depth.append(None)
# create random grid
random_grid = {
 'n_estimators': n_estimators,
 'max_features': max_features,
 'max_depth': max_depth
 }
# Random search of parameters
rfc_random = RandomizedSearchCV(estimator = rfc, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the model
rfc_random.fit(X_train, y_train)
# print results
print(rfc_random.best_params_)

# %%
rfc = RandomForestClassifier(n_estimators=600, max_depth=300, max_features='sqrt')
rfc.fit(X_train,y_train)
rfc_predict = rfc.predict(X_test)
rfc_cv_score = cross_val_score(rfc, X, y, cv=10, scoring='roc_auc')
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, rfc_predict))
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Random Forest: ", rfc_cv_score.mean())
# Out:
# === Confusion Matrix ===
# [[39  7]
#  [12  1]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80        46
#            1       0.12      0.08      0.10        13
#
#     accuracy                           0.68        59
#    macro avg       0.44      0.46      0.45        59
# weighted avg       0.62      0.68      0.65        59
#
#
#
# === All AUC Scores ===
# [0.64285714 0.53571429 0.8        0.66153846 0.83076923 0.4
#  0.63076923 0.67307692 0.36538462 0.40384615]
#
#
# === Mean AUC Score ===
# Mean AUC Score - Random Forest:  0.5943956043956043
