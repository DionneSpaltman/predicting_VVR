# %% [markdown]
# # Visualization of VVR groups
# Everything you need to know about matplotlib can be find in its documentation: https://matplotlib.org/stable/

# %%
# %matplotlib inline 
import numpy
import pandas
import matplotlib.pyplot as plt

# %%
merged_df = pandas.read_csv('/Users/dionnespaltman/Desktop/V6/merged_df_11-06-2024.csv')
display(merged_df)
# Out:
#      Unnamed: 0   ID  Stage  Gender        Date  Location  Condition  \
# 0             0    7    1.0       2  2019-10-28         0          2
# 1             1   23    1.0       2  2020-08-01         1          2
# 2             2   24    1.0       2  2020-01-22         1          2
# 3             3   25    1.0       2  2020-05-02         1          2
# 4             4   26    1.0       1  2020-06-02         2          1
# ..          ...  ...    ...     ...         ...       ...        ...
# 273         273  323    1.0       2  2022-10-26         3          3
# 274         274  325    1.0       2  2022-07-11         3          3
# 275         275  329    1.0       2  2022-11-28         3          3
# 276         276  330    1.0       2  2022-11-30         0          3
# 277         277  331    1.0       2  2022-11-30         0          3
#
#      Faintness  Dizziness  Weakness  ...  AU26_r__standard_deviation  \
# ...

# %%
filtered_donor_info = pandas.read_csv('/Users/dionnespaltman/Desktop/V6/filtered_donor_info_11-06-2024.csv')
display(filtered_donor_info)
# Out:
#       Unnamed: 0   ID  Stage  Gender   Age        Date  Location  Condition  \
# 0              0    7    1.0       2  25.0  2019-10-28         0          2
# 1              1    7    2.0       2  25.0  2019-10-28         0          2
# 2              2    7    3.0       2  25.0  2019-10-28         0          2
# 3              3    7    4.0       2  25.0  2019-10-28         0          2
# 4              4    7    5.0       2  25.0  2019-10-28         0          2
# ...          ...  ...    ...     ...   ...         ...       ...        ...
# 1774        1774  331    2.0       2  56.0  2022-11-30         0          3
# 1775        1775  331    4.0       2  56.0  2022-11-30         0          3
# 1776        1776  331    5.0       2  56.0  2022-11-30         0          3
# 1777        1777  331    6.0       2  56.0  2022-11-30         0          3
# 1778        1778  331    7.0       2  56.0  2022-11-30         0          3
#
# ...

# %%
unique_ids = filtered_donor_info['ID'].nunique()
print(unique_ids)
# Out:
# 278

# %% [markdown]
# ## 1st graph
# - On the y-axis the number of donors.
# - On the x-axis the VVR during and post donation scores (stages 4, 5, 6, 7).
# - Bar graph with condition.
# - Adding a dotted graph where the mean is (mean = 30.515625)

# %%
display(filtered_donor_info)
# Out:
#       Unnamed: 0   ID  Stage  Gender   Age        Date  Location  Condition  \
# 0              0    7    1.0       2  25.0  2019-10-28         0          2
# 1              1    7    2.0       2  25.0  2019-10-28         0          2
# 2              2    7    3.0       2  25.0  2019-10-28         0          2
# 3              3    7    4.0       2  25.0  2019-10-28         0          2
# 4              4    7    5.0       2  25.0  2019-10-28         0          2
# ...          ...  ...    ...     ...   ...         ...       ...        ...
# 1774        1774  331    2.0       2  56.0  2022-11-30         0          3
# 1775        1775  331    4.0       2  56.0  2022-11-30         0          3
# 1776        1776  331    5.0       2  56.0  2022-11-30         0          3
# 1777        1777  331    6.0       2  56.0  2022-11-30         0          3
# 1778        1778  331    7.0       2  56.0  2022-11-30         0          3
#
# ...

# %%
# Calculate the minimum and maximum values of the column
min_value = filtered_donor_info['Sum_12'].min()
max_value = filtered_donor_info['Sum_12'].max()

print("Range of 'sum_12' column:")
print("Minimum value:", min_value)
print("Maximum value:", max_value)
# Out:
# Range of 'sum_12' column:
# Minimum value: 16.0
# Maximum value: 42.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
plt.style.use('seaborn-darkgrid')

# Define font size and font name
font_size = 14
font_name = 'Times New Roman'

# Filter the DataFrame to include only rows with VVR sum scores between 10 and 100
filtered_df = filtered_donor_info[(filtered_donor_info['Sum_4567'] >= 10) & (filtered_donor_info['Sum_4567'] <= 100)]

# Create a stacked histogram
plt.hist([filtered_df[filtered_df['Condition'] == 1]['Sum_4567'],
          filtered_df[filtered_df['Condition'] == 2]['Sum_4567'],
          filtered_df[filtered_df['Condition'] == 3]['Sum_4567']],
         bins=20, color=['#1f77b4', '#ff7f0e', '#2ca02c'], alpha=0.7, stacked=True,
         label=['Experienced donors (control group)',
                'Sensitive donors (experimental group)',
                'First-time donors'])

# Add a vertical dotted line for the mean (June 13, 2024)
mean_value = 39.770657672849914
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean ({mean_value:.2f})')

# Set labels and title
plt.xlabel('Sum of self-reported VVR levels', fontsize=font_size, fontname=font_name)
plt.ylabel('Number of Donors', fontsize=font_size, fontname=font_name)
# plt.title('Stacked Histogram of sum of self-reported VVR levels by Condition (N = 278)', fontsize=font_size, fontname=font_name)

# Add legend with Times New Roman font
plt.legend(prop={'family': font_name, 'size': font_size})

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Increase the font size of ticks
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_3788/1318264257.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # 2nd graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style 
plt.style.use('seaborn-darkgrid')

# Define font size and font name
font_size = 14
title_font_size = 16
tick_font_size = 12
font_name = 'Times New Roman'

# Filter the DataFrame to include only rows with VVR sum scores between 10 and 100
filtered_df = filtered_donor_info[(filtered_donor_info['Sum_4567'] >= 10) & (filtered_donor_info['Sum_4567'] <= 100)]

# Create a stacked histogram
plt.hist([filtered_df[filtered_df['Gender'] == 1]['Sum_4567'],
          filtered_df[filtered_df['Gender'] == 2]['Sum_4567']],
         bins=20, color=['#1f77b4', '#ff7f0e'], alpha=0.7, stacked=True,
         label=['Men', 'Women'])

# Add a vertical dotted line for the mean (June 13, 2024)
mean_value = 39.770657672849914
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean ({mean_value:.2f})')

# Set labels and title
plt.xlabel('Sum of self-reported VVR levels', fontsize=font_size, fontname=font_name)
plt.ylabel('Number of Donors', fontsize=font_size, fontname=font_name)
# plt.title('Stacked Histogram of sum of self-reported VVR levels by Gender (N = 278)', fontsize=title_font_size, fontname=font_name)

# Add legend with Times New Roman font
plt.legend(prop={'family': font_name, 'size': font_size})

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Increase the font size of ticks
plt.xticks(fontsize=tick_font_size)
plt.yticks(fontsize=tick_font_size)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_36236/911320631.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # 3rd graph
# - On the x-axis the 'Stage'. There should be 7 times 3 box plots. So three plots per each stage. The three plots are one per Condition (1 = control, 2 = experimental and 3 = sensitive)/
# - On the y-axis the VVR ratings.
# - clean_donor_info is the dataframe where all the information is.

# %%
print(filtered_donor_info.shape)
# Out:
# (1779, 27)

# %%
display(filtered_donor_info)
# Out:
#       Unnamed: 0   ID  Stage  Gender   Age        Date  Location  Condition  \
# 0              0    7    1.0       2  25.0  2019-10-28         0          2
# 1              1    7    2.0       2  25.0  2019-10-28         0          2
# 2              2    7    3.0       2  25.0  2019-10-28         0          2
# 3              3    7    4.0       2  25.0  2019-10-28         0          2
# 4              4    7    5.0       2  25.0  2019-10-28         0          2
# ...          ...  ...    ...     ...   ...         ...       ...        ...
# 1774        1774  331    2.0       2  56.0  2022-11-30         0          3
# 1775        1775  331    4.0       2  56.0  2022-11-30         0          3
# 1776        1776  331    5.0       2  56.0  2022-11-30         0          3
# 1777        1777  331    6.0       2  56.0  2022-11-30         0          3
# 1778        1778  331    7.0       2  56.0  2022-11-30         0          3
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
plt.style.use('seaborn-darkgrid')

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

font_size = 18
font_name = 'Times New Roman'

# Define the order and labels of conditions
condition_order = [1, 2, 3]
condition_labels = ['Experienced donors (control group)', 'Sensitive donors (experimental group)', 'First-time donors']

# Define the labels for the stages
stage_labels = ['Waiting room (1)', 'Waiting room (2)', 'Waiting room (3)', 'Needle insertion (4)', 'Donated 300 ml (5)', 'Needle uncoupling (6)', 'Waiting room (7)']

# Plot boxplots for each stage and condition
sns.boxplot(x='Stage', y='Sum_VVR', hue='Condition', data=filtered_donor_info, order=range(1, 8), hue_order=condition_order, linewidth=0.5, flierprops=dict(marker='o', markersize=3))

# Move the legend to the right of the graph
handles, _ = ax.get_legend_handles_labels()
plt.legend(handles, condition_labels, bbox_to_anchor=(1.05, 1), loc='upper left', prop={'family': font_name, 'size': 16})

# Set labels for x-axis and y-axis and title
plt.xlabel('Stage', fontsize=font_size, fontname=font_name)
plt.ylabel('Self-reported VVR levels', fontsize=font_size, fontname=font_name)
# plt.title('Self-reported VVR levels by Stage and Condition (N = 278)', fontsize=16, fontname=font_name)

# Set custom labels for the x-axis with a tilt
ax.set_xticklabels(stage_labels, fontsize=font_size, fontname=font_name, rotation=45, ha='right')

# Set font size and font name for y-axis tick labels
ax.tick_params(axis='y', labelsize=font_size)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontname(font_name)

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_3788/861571905.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_3788/861571905.py:38: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontname(font_name)
