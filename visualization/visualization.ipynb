# %% [markdown]
# # Visualization of VVR groups
# Everything you need to know about matplotlib can be find in its documentation: https://matplotlib.org/stable/

# %%
# %matplotlib inline 
import numpy
import pandas
import matplotlib.pyplot as plt

# %%
filtered_donor_info = pandas.read_csv('/Users/dionnespaltman/Desktop/V6/filtered_donor_info_03-06-2024.csv')
display(filtered_donor_info)
# Out:
#      Unnamed: 0   ID  Stage  Gender   Age        Date  Location  Condition  \
# 0             0   23    1.0       2  27.0  2020-08-01         1          2
# 1             1   23    2.0       2  27.0  2020-08-01         1          2
# 2             2   23    3.0       2  27.0  2020-08-01         1          2
# 3             3   23    4.0       2  27.0  2020-08-01         1          2
# 4             4   23    5.0       2  27.0  2020-08-01         1          2
# ..          ...  ...    ...     ...   ...         ...       ...        ...
# 705         705  146    2.0       2  44.0  2021-02-06         0          2
# 706         706  146    4.0       2  44.0  2021-02-06         0          2
# 707         707  146    5.0       2  44.0  2021-02-06         0          2
# 708         708  146    6.0       2  44.0  2021-02-06         0          2
# 709         709  146    7.0       2  44.0  2021-02-06         0          2
#
#      Weight  Length  ...  Nervousness  Physical_sum  Psychological_sum  \
# 0      70.0   160.0  ...          2.0           6.0                7.0
# 1      70.0   160.0  ...          2.0           4.0                7.0
# 2      70.0   160.0  ...          2.0           5.0                6.0
# 3      70.0   160.0  ...          2.0           4.0                6.0
# 4      70.0   160.0  ...          1.0           4.0                4.0
# ..      ...     ...  ...          ...           ...                ...
# 705    64.0   169.0  ...          2.0           4.0                7.0
# 706    64.0   169.0  ...          3.0           4.0                8.0
# 707    64.0   169.0  ...          1.0           5.0                5.0
# 708    64.0   169.0  ...          1.0           5.0                5.0
# 709    64.0   169.0  ...          1.0           4.0                4.0
#
#      Sum_VVR  Sum_12  Sum_456  Sum_4567  Sum_1  Sum_2  VVR_group
# 0       13.0    24.0     27.0      37.0   13.0   11.0          0
# 1       11.0    24.0     27.0      37.0   13.0   11.0          0
# 2       11.0    24.0     27.0      37.0   13.0   11.0          0
# 3       10.0    24.0     27.0      37.0   13.0   11.0          0
# 4        8.0    24.0     27.0      37.0   13.0   11.0          0
# ..       ...     ...      ...       ...    ...    ...        ...
# 705     11.0    22.0     32.0      40.0   11.0   11.0          1
# 706     12.0    22.0     32.0      40.0   11.0   11.0          1
# 707     10.0    22.0     32.0      40.0   11.0   11.0          1
# 708     10.0    22.0     32.0      40.0   11.0   11.0          1
# 709      8.0    22.0     32.0      40.0   11.0   11.0          1
#
# [710 rows x 27 columns]

# %% [markdown]
# ## 1st graph
# - On the y-axis the number of donors.
# - On the x-axis the VVR during and post donation scores (stages 4, 5, 6, 7).
# - Bar graph with condition.
# - Adding a dotted graph where the mean is (mean = 30.515625)

# %%
display(filtered_donor_info)
# Out:
#      Unnamed: 0   ID  Stage  Gender   Age        Date  Location  Condition  \
# 0             0   23    1.0       2  27.0  2020-08-01         1          2
# 1             1   23    2.0       2  27.0  2020-08-01         1          2
# 2             2   23    3.0       2  27.0  2020-08-01         1          2
# 3             3   23    4.0       2  27.0  2020-08-01         1          2
# 4             4   23    5.0       2  27.0  2020-08-01         1          2
# ..          ...  ...    ...     ...   ...         ...       ...        ...
# 705         705  146    2.0       2  44.0  2021-02-06         0          2
# 706         706  146    4.0       2  44.0  2021-02-06         0          2
# 707         707  146    5.0       2  44.0  2021-02-06         0          2
# 708         708  146    6.0       2  44.0  2021-02-06         0          2
# 709         709  146    7.0       2  44.0  2021-02-06         0          2
#
#      Weight  Length  ...  Nervousness  Physical_sum  Psychological_sum  \
# 0      70.0   160.0  ...          2.0           6.0                7.0
# 1      70.0   160.0  ...          2.0           4.0                7.0
# 2      70.0   160.0  ...          2.0           5.0                6.0
# 3      70.0   160.0  ...          2.0           4.0                6.0
# 4      70.0   160.0  ...          1.0           4.0                4.0
# ..      ...     ...  ...          ...           ...                ...
# 705    64.0   169.0  ...          2.0           4.0                7.0
# 706    64.0   169.0  ...          3.0           4.0                8.0
# 707    64.0   169.0  ...          1.0           5.0                5.0
# 708    64.0   169.0  ...          1.0           5.0                5.0
# 709    64.0   169.0  ...          1.0           4.0                4.0
#
#      Sum_VVR  Sum_12  Sum_456  Sum_4567  Sum_1  Sum_2  VVR_group
# 0       13.0    24.0     27.0      37.0   13.0   11.0          0
# 1       11.0    24.0     27.0      37.0   13.0   11.0          0
# 2       11.0    24.0     27.0      37.0   13.0   11.0          0
# 3       10.0    24.0     27.0      37.0   13.0   11.0          0
# 4        8.0    24.0     27.0      37.0   13.0   11.0          0
# ..       ...     ...      ...       ...    ...    ...        ...
# 705     11.0    22.0     32.0      40.0   11.0   11.0          1
# 706     12.0    22.0     32.0      40.0   11.0   11.0          1
# 707     10.0    22.0     32.0      40.0   11.0   11.0          1
# 708     10.0    22.0     32.0      40.0   11.0   11.0          1
# 709      8.0    22.0     32.0      40.0   11.0   11.0          1
#
# [710 rows x 27 columns]

# %%
# Calculate the minimum and maximum values of the column
min_value = filtered_donor_info['Sum_12'].min()
max_value = filtered_donor_info['Sum_12'].max()

print("Range of 'sum_12' column:")
print("Minimum value:", min_value)
print("Maximum value:", max_value)
# Out:
# Range of 'sum_12' column:
# Minimum value: 16.0
# Maximum value: 42.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
plt.style.use('seaborn-darkgrid')

# Filter the DataFrame to include only rows with VVR sum scores between 10 and 100
filtered_df = filtered_donor_info[(filtered_donor_info['Sum_4567'] >= 10) & (filtered_donor_info['Sum_4567'] <= 100)]

# Create a stacked histogram
plt.hist([filtered_df[filtered_df['Condition'] == 1]['Sum_4567'],
          filtered_df[filtered_df['Condition'] == 2]['Sum_4567'],
          filtered_df[filtered_df['Condition'] == 3]['Sum_4567']],
         bins=20, color=['#1f77b4', '#ff7f0e', '#2ca02c'], alpha=0.7, stacked=True,
         label=['Control group (experienced donors)',
                'Experimental group (sensitive donors)',
                'First-time donors'])

# Add a vertical dotted line for the mean
mean_value = 37.61267605633803
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean ({mean_value:.2f})')

# Set labels and title
plt.xlabel('VVR Sum Score', fontsize=14, fontname='Times New Roman')
plt.ylabel('Number of Donors', fontsize=14, fontname='Times New Roman')
plt.title('Stacked Histogram of VVR Sum Scores by Condition (N = 111)', fontsize=16, fontname='Times New Roman')

# Add legend with Times New Roman font
plt.legend(prop={'family': 'Times New Roman'})

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Increase the font size of ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_17653/3394560381.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # 2nd graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style 
plt.style.use('seaborn-darkgrid')

# Filter the DataFrame to include only rows with VVR sum scores between 10 and 100
filtered_df = filtered_donor_info[(filtered_donor_info['Sum_4567'] >= 10) & (filtered_donor_info['Sum_4567'] <= 100)]

# Create a stacked histogram
plt.hist([filtered_df[filtered_df['Gender'] == 1]['Sum_4567'],
          filtered_df[filtered_df['Gender'] == 2]['Sum_4567']],
         bins=20, color=['#1f77b4', '#ff7f0e'], alpha=0.7, stacked=True,
         label=['Men',
                'Women'])
# Add a vertical dotted line for the mean
mean_value = 37.61561561561562
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean ({mean_value:.2f})')

# Set labels and title
plt.xlabel('VVR Sum Score', fontsize=14, fontname='Times New Roman')
plt.ylabel('Number of Donors', fontsize=14, fontname='Times New Roman')
plt.title('Stacked Histogram of VVR Sum Scores by Gender (N = 111)', fontsize=16, fontname='Times New Roman')

# Add legend with Times New Roman font
plt.legend(prop={'family': 'Times New Roman'})

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Increase the font size of ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_1464/4057912432.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # 3rd graph
# - On the x-axis the 'Stage'. There should be 7 times 3 box plots. So three plots per each stage. The three plots are one per Condition (1 = control, 2 = experimental and 3 = sensitive)/
# - On the y-axis the VVR ratings.
# - clean_donor_info is the dataframe where all the information is.

# %%
filtered_donor_info = pandas.read_csv("/Users/dionnespaltman/Desktop/V6/filtered_donor_info_03-06-2024.csv")

print(filtered_donor_info.shape)
# Out:
# (710, 27)

# %%
display(filtered_donor_info)
# Out:
#      Unnamed: 0   ID  Stage  Gender   Age        Date  Location  Condition  \
# 0             0   23    1.0       2  27.0  2020-08-01         1          2
# 1             1   23    2.0       2  27.0  2020-08-01         1          2
# 2             2   23    3.0       2  27.0  2020-08-01         1          2
# 3             3   23    4.0       2  27.0  2020-08-01         1          2
# 4             4   23    5.0       2  27.0  2020-08-01         1          2
# ..          ...  ...    ...     ...   ...         ...       ...        ...
# 705         705  146    2.0       2  44.0  2021-02-06         0          2
# 706         706  146    4.0       2  44.0  2021-02-06         0          2
# 707         707  146    5.0       2  44.0  2021-02-06         0          2
# 708         708  146    6.0       2  44.0  2021-02-06         0          2
# 709         709  146    7.0       2  44.0  2021-02-06         0          2
#
#      Weight  Length  ...  Nervousness  Physical_sum  Psychological_sum  \
# 0      70.0   160.0  ...          2.0           6.0                7.0
# 1      70.0   160.0  ...          2.0           4.0                7.0
# 2      70.0   160.0  ...          2.0           5.0                6.0
# 3      70.0   160.0  ...          2.0           4.0                6.0
# 4      70.0   160.0  ...          1.0           4.0                4.0
# ..      ...     ...  ...          ...           ...                ...
# 705    64.0   169.0  ...          2.0           4.0                7.0
# 706    64.0   169.0  ...          3.0           4.0                8.0
# 707    64.0   169.0  ...          1.0           5.0                5.0
# 708    64.0   169.0  ...          1.0           5.0                5.0
# 709    64.0   169.0  ...          1.0           4.0                4.0
#
#      Sum_VVR  Sum_12  Sum_456  Sum_4567  Sum_1  Sum_2  VVR_group
# 0       13.0    24.0     27.0      37.0   13.0   11.0          0
# 1       11.0    24.0     27.0      37.0   13.0   11.0          0
# 2       11.0    24.0     27.0      37.0   13.0   11.0          0
# 3       10.0    24.0     27.0      37.0   13.0   11.0          0
# 4        8.0    24.0     27.0      37.0   13.0   11.0          0
# ..       ...     ...      ...       ...    ...    ...        ...
# 705     11.0    22.0     32.0      40.0   11.0   11.0          1
# 706     12.0    22.0     32.0      40.0   11.0   11.0          1
# 707     10.0    22.0     32.0      40.0   11.0   11.0          1
# 708     10.0    22.0     32.0      40.0   11.0   11.0          1
# 709      8.0    22.0     32.0      40.0   11.0   11.0          1
#
# [710 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
plt.style.use('seaborn-darkgrid')

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Define the order and labels of conditions
condition_order = [1, 2, 3]
condition_labels = ['Control group/Experienced donors', 'Sensitive donors', 'New donors']

# Define the labels for the stages
stage_labels = ['Waiting room (1)', 'Waiting room (2)', 'Waiting room (3)', 'Needle insertion (4)', 'Donated 300 ml (5)', 'Needle uncoupling (6)', 'Waiting room (7)']

# Plot boxplots for each stage and condition
sns.boxplot(x='Stage', y='Sum_VVR', hue='Condition', data=filtered_donor_info, order=range(1, 8), hue_order=condition_order, linewidth=0.5, flierprops=dict(marker='o', markersize=3))

# Move the legend to the right of the graph
handles, _ = ax.get_legend_handles_labels()
plt.legend(handles, condition_labels, bbox_to_anchor=(1.05, 1), loc='upper left', prop={'family': 'Times New Roman'})

# Set labels for x-axis and y-axis and title
plt.xlabel('Stage', fontsize=14, fontname='Times New Roman')
plt.ylabel('VVR measurements', fontsize=14, fontname='Times New Roman')
plt.title('VVR Measurements by Stage and Condition (N = 111)', fontsize=16, fontname='Times New Roman')

# Set custom labels for the x-axis with a tilt
ax.set_xticklabels(stage_labels, fontsize=12, fontname='Times New Roman', rotation=45, ha='right')

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show the plot
plt.show()
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_1464/1977234814.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
